# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Tanjoh Noel Nchong**
#
# Data Scientist

# %% [markdown]
# _I am interested in data science because I love storytelling with data_
#
# _I am interested in data science because data vizualization_

# %% [markdown]
# ### Compare Two Numbers

# %%
1 > 3
# Out:
# False

# %% [markdown]
# **Open Source Tools In Data Science**
# * Jupyter Notebook and JupyterLab
# * RStudio IDE
# * GitHub
#
# **Other IBM Tools for Data Science**
# 1. Watson Studio
# 2. IBM Watson Knowledge Catalog
# 3. Data Refinery
# 4. IBM SPSS Modeler
# 5. SPSS Statistics
# 6. Auto AI
#
# Learn Data Science on [Coursera](https://www.coursera.org/)
#
# |Week 1 | Week 2 | Week 3 | Week 4 |
# |:----  |:----:  |:----:  | ----:  |
# |    a  |     b  |   c    |    d   |
# |    i  |     ii |   iii  |    iv  |
